# %% [markdown]
# # Lab - 4 - Data Preprocessing

# %% [markdown]
# ### 1)  First, you need to read the titanic dataset from local disk and display Last five records

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('titanic.csv')
data

# %%
data2 = data.copy()
data2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data2.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data2.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# ### 2)  Handle Missing Values in data set [use dropna(), fillna(), and interpolate]

# %%
data_dropnaAll = data2.dropna(how='all')
data_dropna = data2.dropna()
data_dropna.count()
# axis:
# Specifies whether to drop rows or columns.
# 0 or 'index' (default): Drops rows containing missing values.
# 1 or 'columns': Drops columns containing missing values.
# Out:
# PassengerId    183
# Survived       183
# Pclass         183
# Name           183
# Sex            183
# Age            183
# SibSp          183
# Parch          183
# Ticket         183
# Fare           183
# Cabin          183
# Embarked       183
# dtype: int64

# %%
data_fillna = data2.fillna({'Age' : 35,'Cabin' : 'Not Available'})
# data_fillna = data2.fillna(35)
data_fillna
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  35.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare          Cabin Embarked
# 0        0         A/5 21171   7.2500  Not Available        S
# 1        0          PC 17599  71.2833            C85        C
# 2        0  STON/O2. 3101282   7.9250  Not Available        S
# 3        0            113803  53.1000           C123        S
# 4        0            373450   8.0500  Not Available        S
# ..     ...               ...      ...            ...      ...
# 886      0            211536  13.0000  Not Available        S
# 887      0            112053  30.0000            B42        S
# 888      2        W./C. 6607  23.4500  Not Available        S
# 889      0            111369  30.0000           C148        C
# 890      0            370376   7.7500  Not Available        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ### 3)  Apply Scaling to AGE attribute with min max, decimal scaling and z score.

# %%
age_mean = data2.Age.mean()
age_mean
fill_data = data2.fillna({'Age' : age_mean})
fill_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data2['Age'].min()
# Out:
# 0.42

# %%
data['Age'].max()
# Out:
# 80.0

# %%
data_interpolation = data2.interpolate()
data_interpolation
# Out:
# C:\Users\dholn\AppData\Local\Temp\ipykernel_13176\3603189312.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data_interpolation = data2.interpolate()
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  22.5      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data2.fillna(data2.Age.mean(),inplace=True)

# %%
minAge = data2.Age.min()
maxAge = data2.Age.max()
data2['MinMaxAge'] = (data2['Age']-minAge)/(maxAge-minAge)
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare      Cabin Embarked  MinMaxAge
# 0        1      0         A/5 21171   7.2500  29.699118        S   0.271174
# 1        1      0          PC 17599  71.2833        C85        C   0.472229
# 2        0      0  STON/O2. 3101282   7.9250  29.699118        S   0.321438
# 3        1      0            113803  53.1000       C123        S   0.434531
# 4        0      0            373450   8.0500  29.699118        S   0.434531
# ..     ...    ...               ...      ...        ...      ...        ...
# 886      0      0            211536  13.0000  29.699118        S   0.334004
# 887      0      0            112053  30.0000        B42        S   0.233476
# 888      1      2        W./C. 6607  23.4500  29.699118        S   0.367921
# 889      0      0            111369  30.0000       C148        C   0.321438
# 890      0      0            370376   7.7500  29.699118        Q   0.396833
#
# [891 rows x 13 columns]

# %%
data2.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare       Cabin  \
# count   891.000000  891.000000  891.000000     891  891.000000  891.000000
# unique         NaN         NaN         NaN     681         NaN  148.000000
# top            NaN         NaN         NaN  347082         NaN   29.699118
# freq           NaN         NaN         NaN       7         NaN  687.000000
# mean     29.699118    0.523008    0.381594     NaN   32.204208         NaN
# std      13.002015    1.102743    0.806057     NaN   49.693429         NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000         NaN
# 25%      22.000000    0.000000    0.000000     NaN    7.910400         NaN
# 50%      29.699118    0.000000    0.000000     NaN   14.454200         NaN
# 75%      35.000000    1.000000    0.000000     NaN   31.000000         NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200         NaN
#
#        Embarked   MinMaxAge
# count       891  891.000000
# unique        4         NaN
# top           S         NaN
# freq        644         NaN
# mean        NaN    0.367921
# std         NaN    0.163383
# min         NaN    0.000000
# 25%         NaN    0.271174
# 50%         NaN    0.367921
# 75%         NaN    0.434531
# max         NaN    1.000000

# %%
maxAge = data2.Age.max()
noOfDigits = len(str(int(maxAge)))
noOfDigits
# Out:
# 2

# %%
data2['AgeDS'] = data2['Age']/(10**noOfDigits)

# %%
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare      Cabin Embarked  MinMaxAge  \
# 0        1      0         A/5 21171   7.2500  29.699118        S   0.271174
# 1        1      0          PC 17599  71.2833        C85        C   0.472229
# 2        0      0  STON/O2. 3101282   7.9250  29.699118        S   0.321438
# 3        1      0            113803  53.1000       C123        S   0.434531
# 4        0      0            373450   8.0500  29.699118        S   0.434531
# ..     ...    ...               ...      ...        ...      ...        ...
# 886      0      0            211536  13.0000  29.699118        S   0.334004
# 887      0      0            112053  30.0000        B42        S   0.233476
# 888      1      2        W./C. 6607  23.4500  29.699118        S   0.367921
# 889      0      0            111369  30.0000       C148        C   0.321438
# 890      0      0            370376   7.7500  29.699118        Q   0.396833
#
#         AgeDS
# 0    0.220000
# 1    0.380000
# 2    0.260000
# 3    0.350000
# 4    0.350000
# ..        ...
# 886  0.270000
# 887  0.190000
# 888  0.296991
# 889  0.260000
# 890  0.320000
#
# [891 rows x 14 columns]

# %%
mins = data2.Age.min()
stds = data2.Age.std()
data2['ageScore'] = (data2['Age'] - mins)/stds
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare      Cabin Embarked  MinMaxAge  \
# 0        1      0         A/5 21171   7.2500  29.699118        S   0.271174
# 1        1      0          PC 17599  71.2833        C85        C   0.472229
# 2        0      0  STON/O2. 3101282   7.9250  29.699118        S   0.321438
# 3        1      0            113803  53.1000       C123        S   0.434531
# 4        0      0            373450   8.0500  29.699118        S   0.434531
# ..     ...    ...               ...      ...        ...      ...        ...
# 886      0      0            211536  13.0000  29.699118        S   0.334004
# 887      0      0            112053  30.0000        B42        S   0.233476
# 888      1      2        W./C. 6607  23.4500  29.699118        S   0.367921
# 889      0      0            111369  30.0000       C148        C   0.321438
# 890      0      0            370376   7.7500  29.699118        Q   0.396833
#
#         AgeDS  ageScore
# 0    0.220000  1.659743
# 1    0.380000  2.890321
# 2    0.260000  1.967387
# 3    0.350000  2.659588
# 4    0.350000  2.659588
# ..        ...       ...
# 886  0.270000  2.044298
# 887  0.190000  1.429009
# 888  0.296991  2.251891
# 889  0.260000  1.967387
# 890  0.320000  2.428854
#
# [891 rows x 15 columns]
